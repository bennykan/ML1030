# %%
import pandas as pd
import datetime

data_path = "C:/Users/benny/OneDrive/Machine Learning/ML1030/Final Project/20181007.08-NFL-MIN@PHI-data.csv"
data = pd.read_csv(data_path)

# %%
print(data)
data.describe()
# Out:
#                                          Date         Book  Away Moneyline  \
# 0     Mon Oct 01 2018 00:43:34 GMT+0000 (UTC)  CharlieBook             NaN
# 1     Mon Oct 01 2018 01:43:34 GMT+0000 (UTC)  CharlieBook             NaN
# 2     Mon Oct 01 2018 02:43:34 GMT+0000 (UTC)  CharlieBook             NaN
# 3     Mon Oct 01 2018 03:43:34 GMT+0000 (UTC)  CharlieBook             NaN
# 4     Mon Oct 01 2018 04:43:34 GMT+0000 (UTC)  CharlieBook             NaN
# 5     Mon Oct 01 2018 05:43:34 GMT+0000 (UTC)  CharlieBook             NaN
# 6     Mon Oct 01 2018 06:43:33 GMT+0000 (UTC)  CharlieBook             NaN
# 7     Mon Oct 01 2018 07:43:35 GMT+0000 (UTC)  CharlieBook             NaN
# 8     Mon Oct 01 2018 08:43:34 GMT+0000 (UTC)  CharlieBook             NaN
# 9     Mon Oct 01 2018 09:43:34 GMT+0000 (UTC)  CharlieBook             NaN
# 10    Mon Oct 01 2018 10:43:34 GMT+0000 (UTC)  CharlieBook             NaN
# ...

# %%
data["timestamp"] = data.Date.str.slice(0,24)
print(data.timestamp)
# Out:
# 0       Mon Oct 01 2018 00:43:34
# 1       Mon Oct 01 2018 01:43:34
# 2       Mon Oct 01 2018 02:43:34
# 3       Mon Oct 01 2018 03:43:34
# 4       Mon Oct 01 2018 04:43:34
# 5       Mon Oct 01 2018 05:43:34
# 6       Mon Oct 01 2018 06:43:33
# 7       Mon Oct 01 2018 07:43:35
# 8       Mon Oct 01 2018 08:43:34
# 9       Mon Oct 01 2018 09:43:34
# 10      Mon Oct 01 2018 10:43:34
# 11      Mon Oct 01 2018 11:43:34
# 12      Mon Oct 01 2018 12:43:33
# 13      Mon Oct 01 2018 13:43:34
# 14      Mon Oct 01 2018 14:43:34
# 15      Mon Oct 01 2018 15:43:35
# 16      Mon Oct 01 2018 16:43:33
# 17      Mon Oct 01 2018 17:43:34
# 18      Mon Oct 01 2018 18:43:34
# 19      Mon Oct 01 2018 19:43:34
# 20      Mon Oct 01 2018 20:43:35
# 21      Mon Oct 01 2018 21:43:35
# 22      Mon Oct 01 2018 22:43:33
# 23      Mon Oct 01 2018 23:43:34
# 24      Tue Oct 02 2018 00:43:34
# 25      Tue Oct 02 2018 01:43:34
# 26      Tue Oct 02 2018 02:43:34
# 27      Tue Oct 02 2018 03:43:35
# ...

# %%
data['timestamp'] =  pd.to_datetime(data['timestamp'], format='%a %b %d %Y %H:%M:%S')

# %%
print(data)
# Out:
#                                          Date         Book  Away Moneyline  \
# 0     Mon Oct 01 2018 00:43:34 GMT+0000 (UTC)  CharlieBook             NaN
# 1     Mon Oct 01 2018 01:43:34 GMT+0000 (UTC)  CharlieBook             NaN
# 2     Mon Oct 01 2018 02:43:34 GMT+0000 (UTC)  CharlieBook             NaN
# 3     Mon Oct 01 2018 03:43:34 GMT+0000 (UTC)  CharlieBook             NaN
# 4     Mon Oct 01 2018 04:43:34 GMT+0000 (UTC)  CharlieBook             NaN
# 5     Mon Oct 01 2018 05:43:34 GMT+0000 (UTC)  CharlieBook             NaN
# 6     Mon Oct 01 2018 06:43:33 GMT+0000 (UTC)  CharlieBook             NaN
# 7     Mon Oct 01 2018 07:43:35 GMT+0000 (UTC)  CharlieBook             NaN
# 8     Mon Oct 01 2018 08:43:34 GMT+0000 (UTC)  CharlieBook             NaN
# 9     Mon Oct 01 2018 09:43:34 GMT+0000 (UTC)  CharlieBook             NaN
# 10    Mon Oct 01 2018 10:43:34 GMT+0000 (UTC)  CharlieBook             NaN
# ...

# %%
import matplotlib.pyplot as plt

#df = pd.DataFrame(data.Book,data.timestamp)

#plt.rcParams["figure.figsize"] = (20,3)
#x = data.groupby('Book')

#data_charlie = data[data.Book=='CharlieBook']
#plt.plot(x['timestamp'], x['Away Moneyline'])
#plt.legend(loc='best')    
#plt.show()
